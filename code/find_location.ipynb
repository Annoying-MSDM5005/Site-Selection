# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %run utils.py

# %%
# read geodata of hk
dcca = gpd.read_file("../data/DCCA_21C.geojson").to_crs(epsg=4326)
create_features(dcca)

# %% [markdown]
# ## 1. Find potential candidate locations utilizing experience from other brands' restaurants
#
# We collected the locations of all the restaurants of the following brands:
#
# - McDonald's
# - Fairwood
# - Cafe de Coral
# - KFC
#
# We remove locations of other brands within 1km of Yoshinoya's restaurants. The remaining locations are potential candidate locations for Yoshinoya's new restaurants.
#
# Meanwhile, we also calculate the metric=(Median monthly income)*(Working Population) to evaluate the potential purchasing power of each location.

# %%
# set the hyperparameters
dmin = 1000
gamma = .8
ws = .15
wp = .75
wm = .1

# %%
# read geodata of yoshinoya
yoshi = read_json_data("../data/yoshinoya.json",drop_duplicates=True)
yoshi = set_zone(yoshi,radius=dmin)

# %%
others_path = {
    "Fairwood":"../data/fairwood.json",
    "Cafe de Coral":"../data/cdc.json",
    "McDonald's":"../data/mcdonalds.json",
    "KFC":"../data/kfc.json",
}

store_color = {
    "Fairwood":"white",
    "Cafe de Coral":"orange",
    "McDonald's":"yellow",
    "KFC":"red",
}

# %%
others_dfs = {}
for name in others_path:
    others_dfs[name] = read_json_data(others_path[name])

# %%
others_geometry = concat_geometry(others_dfs.values())
yoshi_zone = yoshi.set_geometry('zone')
difference = dcca.overlay(yoshi_zone,how='difference')
candidates_location = others_geometry.loc[~others_geometry.apply(lambda x: x.within(yoshi_zone.geometry).any())]
hk_boundary = gpd.GeoSeries(difference.unary_union).boundary

# %%
S = 10
fig,ax=plt.subplots(figsize=(S,.6*S))
difference.plot('t_tmmearn',cmap="rainbow",ax=ax,legend=True,legend_kwds={'label': "(Median monthly income)*(Working Population)",'shrink':.6})
hk_boundary.plot(color="grey",ax=ax,lw=2,alpha=.5)
candidates_location.plot(color="k",ax=ax,markersize=2*S,label="Other Brands' Stores")
ax.set_title("{Other Brands - S(Yoshi,R=1km)}")
ax.legend()
plt.savefig("img/site_candidates.png")
plt.show()

# %% [markdown]
# ## 2. Model and calculate value of each candidate location
#
# Define the feature of each candidate and current yoshinoya as the feature of the corresponding district in dataset "DCCA_21C.json" which includes data of demography and incomes.
#
# First, let us define the "Modified Similiarity Score" $S$ between the feature of $i^{th}$ feature $Y_i$ and the average feature of current yoshinoya $\bar{X}$ as:
#
# $$
# S(Y_i) = \cos(Y_i,\bar{X})\cdot\sqrt{\frac1{\gamma}\frac{d_i}{d_{\min}}-1}
# $$
#
# where $\cos(\cdot,\cdot)$ is the cosine similarity function, $d_i$ is the distance between candidate location and the nearest current yoshinoya, and $d_{\min}$ is the excluded distance and the $\gamma$ is a hyparameter for closeness penalty.
#
# This the "Modified Similiarity Score" measures how the candidate match the historical standard of stores' location choosing of yoshinoya.
#
# Second, we define the "Potential Purchasing Power" $P$ of each candidate location as:
#
# $$
# P(Y_i) = I_i*W_i
# $$
#
# where $I_i$ is the median monthly income of the $i^{th}$ candidate location and $W_i$ is the working population of the $i^{th}$ candidate location.
#
# The convenience of transportation is an important factor in site selection, so we will take the distance from the subway station into consideration.
#
# Using sigmoid function, the score $M(Y_i)$ is defined as
#
# $$
# M(Y_i) =  1 / (1 + exp((d_i - threshold) / slope))
# $$
#
# where $d_i$ represents the distance from the nearest subway station, threshold and slope are parameters that need to be adjusted.
#
# Then, we define the "Value" $V$ of each candidate location as:
#
# $$
# V(Y_i) = \omega_S S(Y_i) + \omega_P \frac{P(Y_i)}{R(Y_i)} + \omega_M M(Y_i)
# $$
#
# where $R(Y_i)$ is the average rent of the $i^{th}$ candidate location,
# $\omega_S$ and $\omega_P$ are hyparameters for the weight of "Modified Similiarity Score" and "Potential Purchasing Power" respectively.
#
# Finally, we rank the candidates by their "Value" and select the top 5 candidates as the final recommendation.

# %%
rent = gpd.read_file("../data/Shop_and_Other_Commercial_Assessments.geojson").to_crs(epsg=4326)
geodata = gpd.overlay(dcca, rent, how='intersection')
geodata['Shop_RV_HKD_In_Thousand'] = geodata['Shop_RV_HKD_In_Thousand'].astype(float)
geodata['Shop_Number'] = geodata['Shop_Number'].astype(float)
geodata['avg_rent'] = geodata['Shop_RV_HKD_In_Thousand']/geodata['Shop_Number']

# %%
geodata_normed = minmax_normalize(geodata)
yoshi_features = get_features_by_location(geodata_normed,yoshi.geometry)
candidate_features = get_features_by_location(geodata_normed,candidates_location)
yoshi_common_feature = yoshi_features.mean()
sim = cosine_similarity(candidate_features,yoshi_common_feature)
distance = min_distance(candidates_location,yoshi)
# Out:
# /Users/creator/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1443: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)

# %%
candidates = gpd.GeoDataFrame({"s":sim,"d":distance,"geometry":candidates_location,**candidate_features.to_dict()})
candidates['S'] = candidates.s*np.sqrt(1/gamma*candidates.d/dmin-1)
candidates['P'] = candidates.t_tmmearn
candidates['R'] = candidates.avg_rent
candidates['V'] = ws*candidates.S+wp*candidates.P/candidates.R

# %%
candidates
# Out:
#             s             d                    geometry      adhz     age_1  \
# 0    0.919083   1233.128249  POINT (114.22598 22.32540)  0.409091  0.212630
# 2    0.923826   1949.456053  POINT (114.25616 22.32517)  0.409091  0.115458
# 3    0.891458   1547.061874  POINT (114.25745 22.32174)  0.545455  0.370402
# 9    0.976457   1046.004751  POINT (114.14428 22.50080)  0.409091  0.378694
# 11   0.830411   1612.357053  POINT (114.20119 22.39872)  0.681818  0.212418
# ..        ...           ...                         ...       ...       ...
# 621  0.926045   1461.279955  POINT (114.19828 22.39427)  0.545455  0.620030
# 628  0.948274   1140.460274  POINT (114.14332 22.36223)  0.454545  0.328514
# 633  0.826520   1187.072807  POINT (114.11321 22.35675)  0.227273  0.142037
# 646  0.938365   1882.287286  POINT (113.98782 22.41088)  0.636364  0.291729
# 654  0.944956  10831.893551  POINT (113.93967 22.27858)  0.318182  0.559218
#
# ...

# %%
S = 10
fig,ax=plt.subplots(figsize=(S,.6*S))
dcca.plot(color="grey",ax=ax)
candidates.plot("S",cmap="rainbow",ax=ax,legend=True,legend_kwds={'label': "Modified Similiarity Score $S$",'shrink':.6})
ax.set_title("Modified Similiarity Score of Candidates")
plt.savefig("img/sim_candidates.png")
plt.show()

# %%
S = 10
fig,ax=plt.subplots(figsize=(S,S))
dcca.plot(color="grey",ax=ax)
candidates["rate"] = (5-3.5)*minmaxnorm(candidates.P)+3.5
candidates.plot("rate",cmap="rainbow",ax=ax,legend=True,legend_kwds={'label': "Predicted Rating",'shrink':.6})
ax.set_title("Predicted Rating by Potiential Customers in each candidate site")
plt.savefig("img/rating_candidates.png")
plt.show()

# %%
import os
import json

mtr_path = "../data/MTRStations.json"
if not os.path.exists(mtr_path):
    stations_info = get_stations_info()
    with open(mtr_path, "w") as f:
        json.dump(stations_info, f)
else:
    with open(mtr_path, "r") as f:
        stations_info = json.load(f)

stations_info = preprocess(stations_info)
mtr = pd.DataFrame(stations_info)
mtr = gpd.GeoDataFrame({'name':mtr['title']}, geometry=gpd.points_from_xy(mtr.long, mtr.lat)).drop_duplicates()
mtr.set_crs(epsg=4326,inplace=True)
# Out:
#                   name                    geometry
# 0            Admiralty  POINT (114.16472 22.27889)
# 1    Exhibition Centre  POINT (114.17528 22.28167)
# 2             Hung Hom  POINT (114.18167 22.30278)
# 3        Mong Kok East  POINT (114.17278 22.32222)
# 4         Kowloon Tong  POINT (114.17611 22.33694)
# ..                 ...                         ...
# 114  Disneyland Resort  POINT (114.04500 22.31556)
# 116     South Horizons  POINT (114.14917 22.24250)
# 117           Lei Tung  POINT (114.15611 22.24222)
# 118     Wong Chuk Hang  POINT (114.16806 22.24806)
# 119         Ocean Park  POINT (114.17417 22.24861)
#
# [98 rows x 2 columns]

# %%
candidates.set_crs(epsg=4326,inplace=True)
candidates = candidates.to_crs(epsg=2326)
candidates['region'] = candidates.buffer(1000).to_crs(epsg=4326)

# %%
candidates_with_mtr = candidates.loc[candidates.apply(lambda store: mtr.geometry.within(store.region).any(), axis=1)]
mtr_with_candidates = mtr.loc[mtr.apply(lambda station: candidates.region.contains(station.geometry).any(), axis=1)]

# %%
candidates_with_mtr["distan"] = candidates_with_mtr.to_crs(epsg=2326).apply(lambda store: mtr_with_candidates.to_crs(epsg=2326).geometry.distance(store.geometry).min(), axis=1)
# Out:
# /Users/creator/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
print(candidates_with_mtr['distan'])
# Out:
# 2      354.287665
# 3      104.455746
# 11     237.278200
# 13     541.391095
# 27     675.491951
#           ...
# 603    373.575848
# 612    900.739299
# 621    112.179544
# 633    669.222024
# 646    955.786580
# Name: distan, Length: 114, dtype: float64

# %%
threshold = candidates_with_mtr['distan'].mean()
slope = 100
candidates_with_mtr['M'] = 1 / (1 + np.exp((candidates_with_mtr['distan'] - threshold) / slope))
# Out:
# /Users/creator/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
candidates_with_mtr['M'].describe()
# Out:
# count    114.000000
# mean       0.541539
# std        0.352407
# min        0.002216
# 25%        0.177366
# 50%        0.548820
# 75%        0.905400
# max        0.967220
# Name: M, dtype: float64

# %%
candidates_with_mtr['Vm'] = candidates_with_mtr['V'] + wm*candidates_with_mtr['M']
# Out:
# /Users/creator/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
candidates_with_mtr['Vm'].describe()
# Out:
# count    114.000000
# mean       0.828732
# std        0.459875
# min        0.320485
# 25%        0.554954
# 50%        0.706844
# 75%        0.986321
# max        3.068145
# Name: Vm, dtype: float64

# %%
candidates_with_mtr = candidates_with_mtr.to_crs(epsg=4326)

# %%
S = 10
fig,ax=plt.subplots(figsize=(S,.6*S))
dcca.plot(color="grey",ax=ax)
# change the range legend
candidates_with_mtr.plot("Vm",cmap="rainbow",ax=ax,legend=True,legend_kwds={'label': "Value $V$",'shrink':.6})
ax.set_title("Value of Candidates")
plt.savefig("img/value_candidates.png")
plt.show()

# %%
sorted_candidates = candidates_with_mtr.sort_values(by='Vm',ascending=False)
chosen = sorted_candidates[:10]

# %%
chosen = chosen.to_crs(epsg=4326)

S = 10
fig,ax=plt.subplots(figsize=(S,S))
dcca.plot(color="grey",ax=ax)
# change the range legend
chosen.plot("Vm",cmap="rainbow",ax=ax,legend=True,legend_kwds={'label': "Value $V$",'shrink':.6})
ax.set_title("Value of Candidates")

plt.show()
